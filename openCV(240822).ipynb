# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
import numpy as np
color  = np.zeros((height,width,3),np.unit8)
gray = np.zeros((row,cols,1),np.unit8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 color  = np.zeros((height,width,3),np.unit8)
#       3 gray = np.zeros((row,cols,1),np.unit8)
#
# NameError: name 'height' is not defined

# %%
image = cv2.imread("image.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
result = np.zeros((image.shape[0],256), dtype=np.uint8)
hist=cv2.calcHist([image],[0],None,[256],[0,256])
cv2.normalize(hist,hist,0,255,cv2.NORM_MINMAX)
for x,y in enumerate(hist):
    cv2.line(result,(x, image.shape[0]),(x, image.shape[0]-int(y[0])), 255)

dst=np.hstack([image[:,:,0], result])
cv2.imshow("dst",dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:19ef642b-158e-4f4e-a540-e84c93f208af.png)
