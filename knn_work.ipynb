# %%
import pandas as pd
import csv
from pandas import read_csv
file_path='/content/X_test.csv'
f=open(file_path,encoding='utf8')
reader = csv.reader(f)
csv_list=[]
for i in reader:
  csv_list.append(i)
f.close()
log_df = pd.DataFrame(csv_list)
log_df
# Out:
#           0       1      2      3     4      5       6                    7   \
# 0      151.0    7.67   80.0  151.0  7.65   6.07    5.96  0.10800000000000001
# 1      152.0    7.72  -38.8  152.0  7.74  5.925    3.72               0.0661
# 2      152.0     7.8  -1.25  152.0  7.83  5.766    6.06  0.10099999999999999
# 3      152.0    7.63  -57.5  152.0  7.89  5.602     6.0               0.0956
# 4      153.0    7.78  -57.5  153.0  7.95  5.435    4.42  0.07200000000000001
# ...      ...     ...    ...    ...   ...    ...     ...                  ...
# 13237  179.0  3.5625   8.15  179.0   3.5    5.0  -0.941               0.0215
# 13238  178.5   3.535   30.0  178.5   3.5    5.0   -0.78               0.0202
# 13239  178.5  3.5475   17.5  178.5   3.5    5.0   0.501                0.019
# 13240  178.5  3.4475  11.25  178.5   3.5    5.0  -0.298               0.0193
# 13241  178.0  3.5625   1.85  178.0   3.5    5.0    0.34               0.0258
#
# ...
